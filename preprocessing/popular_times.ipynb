# %%
# read parquet file

import pandas as pd
import sys

file_path = '/mnt/disk/data/cache/popular_times.parquet'

data = pd.read_parquet(file_path)

# %%
data.head()
# Out:
#                     safegraph_place_id  place_id  \
# 0  sg:0009ebd63e484ef7b46e4d97ec4d40a0         4
# 1  sg:0034dbd476b240e99909e500df5479c2        28
# 2  sg:003c1e0ad1c743bf9f2f27ccda3b3cf3        37
# 3  sg:005226168e7b4124a9e2aa5db55abeff        49
# 4  sg:00726256547d47168f5b223fc2f3b71b        71
#
#                                             category  num_visits  \
# 0                                     Grocery Stores         117
# 1                                  Gasoline Stations         369
# 2            Automotive Equipment Rental and Leasing         105
# 3  Agencies, Brokerages, and Other Insurance Rela...         111
# 4                                     Grocery Stores         517
#
#                                                daily  \
# 0  [0.0116, 0.0088, 0.0052, 0.0044, 0.0061, 0.008...
# 1  [0.0029, 0.0015, 0.002, 0.0026, 0.0021, 0.002,...
# 2  [0.0017, 0.0005, 0.0003, 0.0016, 0.0021, 0.002...
# 3  [0.0065, 0.0072, 0.0079, 0.0074, 0.0069, 0.008...
# ...

# %%
data.shape
# Out:
# (3587, 6)

# %%
data.iloc[4]['weekly'].sum()
# Out:
# np.float64(1.0003)

# %%
data.iloc[2]['weekly'].shape
# Out:
# (100,)
