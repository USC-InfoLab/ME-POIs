# %%
import pandas as pd

# path to dataset
data_pois = "/mnt/disk/data/POI_data/Safegraph/core_poi-geometry.csv"

# read csv
data_pois = pd.read_csv(data_pois)

# %%
data_pois.shape
# Out:
# (283144, 30)

# %%
data_pois.columns
# Out:
# Index(['placekey', 'safegraph_place_id', 'parent_placekey',
#        'parent_safegraph_place_id', 'safegraph_brand_ids', 'location_name',
#        'brands', 'top_category', 'sub_category', 'naics_code', 'latitude',
#        'longitude', 'street_address', 'city', 'region', 'postal_code',
#        'open_hours', 'category_tags', 'opened_on', 'closed_on',
#        'tracking_opened_since', 'tracking_closed_since', 'polygon_wkt',
#        'polygon_class', 'building_height', 'enclosed', 'phone_number',
#        'is_synthetic', 'includes_parking_lot', 'iso_country_code'],
#       dtype='object')

# %%
data_pois['city'].value_counts()
# Out:
# city
# New York         65030
# Houston          63288
# Los Angeles      50218
# Chicago          48878
# Miami            28530
# San Francisco    27200
# Name: count, dtype: int64

# %%
# keep only the houston pois
data_pois_houston = data_pois[data_pois['city'] == 'Houston']
data_pois_houston.shape
# Out:
# (63288, 30)

# %%
data_pois_houston.columns
# Out:
# Index(['placekey', 'safegraph_place_id', 'parent_placekey',
#        'parent_safegraph_place_id', 'safegraph_brand_ids', 'location_name',
#        'brands', 'top_category', 'sub_category', 'naics_code', 'latitude',
#        'longitude', 'street_address', 'city', 'region', 'postal_code',
#        'open_hours', 'category_tags', 'opened_on', 'closed_on',
#        'tracking_opened_since', 'tracking_closed_since', 'polygon_wkt',
#        'polygon_class', 'building_height', 'enclosed', 'phone_number',
#        'is_synthetic', 'includes_parking_lot', 'iso_country_code'],
#       dtype='object')

# %%
# save to csv
data_pois_houston.to_csv('/mnt/disk/data/POI_data/Safegraph/safegraph_pois_Houston.csv', index=False)
